# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# value counts for categorical data
 
print(df.sex.value_counts(),'\n',df.children.value_counts(),'\n',df.smoker.value_counts(),'\n',df.region.value_counts())
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
#  0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#  no     1064
# yes     274
# Name: smoker, dtype: int64
#  southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# ### Replace with categorical variable with numerical variable
# in columns string value are exist they can not perform arthimatic operation

# %%
df['sex'] = df['sex'].map({'male':1,'female': 0})
df['smoker'] = df['smoker'].map({'yes':1,'no': 0})
df['region'] = df['region'].map({'southeast':0,'southwest': 1,'northeast':3,'northwest':4})

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       1  16884.92400
# 1   18    1  33.770         1       0       0   1725.55230
# 2   28    1  33.000         3       0       0   4449.46200
# 3   33    1  22.705         0       0       4  21984.47061
# 4   32    1  28.880         0       0       4   3866.85520

# %% [markdown]
# ## EDA

# %%
plt.figure(figsize=(13,7))
sns.histplot(df.age, bins = 20, kde=True, color = 'blue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequnecy of each age')
plt.show()

# %% [markdown]
# ### Maximum people in a dataset

# %%
plt.figure(figsize=(13,7))
sns.countplot(x = 'sex', data=df)
plt.title("Gender Distribution")
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
plt.figure(figsize=(13,7))
sns.histplot(df.bmi, bins = 20, kde=True, color = 'red')
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequnecy of each BMI')
plt.show()

# %% [markdown]
# **the majority of people have BMI in between 25 and 40, which is considered as overweight and could be a major factor  in increasing the medical cost

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       1  16884.92400
# 1      18    1  33.770         1       0       0   1725.55230
# 2      28    1  33.000         3       0       0   4449.46200
# 3      33    1  22.705         0       0       4  21984.47061
# 4      32    1  28.880         0       0       4   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       4  10600.54830
# 1334   18    0  31.920         0       0       3   2205.98080
# 1335   18    0  36.850         0       0       0   1629.83350
# 1336   21    0  25.800         0       0       1   2007.94500
# 1337   61    0  29.070         0       1       4  29141.36030
#
# [1338 rows x 7 columns]>

# %% [markdown]
# ## Univariate analysis when we analyze with a single column

# %%
plt.figure(figsize=(13,7))
sns.countplot(x = 'region', data=df)
plt.title("region Distribution")
# Out:
# Text(0.5, 1.0, 'region Distribution')

# %%
plt.figure(figsize=(13,7))
sns.countplot(x = 'children', data=df)
plt.title("childerrn Distribution")
# Out:
# Text(0.5, 1.0, 'childerrn Distribution')

# %%
plt.figure(figsize=(13,7))
sns.histplot(df.charges, bins = 20, kde=True, color = 'green')
plt.title('Charges Distribution')
plt.xlabel('Charges')
plt.ylabel('Distribution of Charges')
plt.show()

# %%
# mostly people lies 0 to 10000 charges and in 50000 to 60000 value people are lying in very few people and small in mid range 20000 to 50000

# %%
## Most of the medical expense are below 20000, with neglible number of patients having a medical expense above 50000

# %% [markdown]
# ## Bi-variate Analysis

# %%
# Relation smoker and age
plt.figure(figsize=(13,7))
sns.catplot(x = 'smoker',kind = 'count', hue='sex',data=df)
plt.xlabel('Smoker')
plt.ylabel('Count')
plt.title('Relation smoker and age')
plt.show()

# %% [markdown]
# ##### we can observe that male smoker in numbers, so I will assume that medical treatment expense for male would be more than female

# %%
plt.figure(figsize=(13,7))


plt.title('Box Plot dor Charges of women')
sns.boxplot(y ='smoker', x='charges', data=df[(df.sex == 0)], orient = 'h')
# Out:
# <Axes: title={'center': 'Box Plot dor Charges of women'}, xlabel='charges', ylabel='smoker'>

# %%
plt.figure(figsize=(13,7))

 
plt.title('Box Plot for Charges of men')
sns.boxplot(y ='smoker', x='charges', data=df[(df.sex == 1)], orient = 'h')
# Out:
# <Axes: title={'center': 'Box Plot for Charges of men'}, xlabel='charges', ylabel='smoker'>

# %% [markdown]
# *The Assumption is that medical expense of males is greater than that of females.In addition to that medical expense of smoker is greater than that of non-smoker

# %%
cor = df.corr()
cor
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019  0.004251  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185 -0.015085  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750 -0.259379  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673  0.014200  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000 -0.047426  0.787251
# region    0.004251 -0.015085 -0.259379  0.014200 -0.047426  1.000000 -0.049444
# charges   0.299008  0.057292  0.198341  0.067998  0.787251 -0.049444  1.000000

# %%
plt.figure(figsize=(13, 7))
sns.heatmap(cor, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ***By observing above plot we can state that smokers has more medical expenses so it has a high impact on insurance charge followed by  age and bmi whereas region, gender and children has no impact.***

# %%
# relation bw smoker and distribution
plt.figure(figsize=(13,7))
sns.catplot(x = 'smoker',y = 'age', kind = 'swarm', data = df)

# %% [markdown]
# #### From the above graph , we cam observe that there is significant number of smoker at the age 19

# %% [markdown]
# ## Multi-variate Analusis

# %%
plt.figure(figsize=(13, 7))

sns.scatterplot(x ='age',y = 'charges',data=df[df.smoker ==0])
plt.title("Scatterplot for charges of non-smoker")
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# *Majority of the points shows that medical expenses increases with the age which may due to the fact that older people are more prone to illness. but there are some outlier which shows illness or expense which may lead to increase in medical expense

# %%
plt.figure(figsize=(13, 7))

sns.scatterplot(x ='age',y = 'charges',data=df[df.smoker ==1])
plt.title("Scatterplot for charges of smoker")
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# In this graph there are two segements,one with medical expense which may due to smoking related illness and other with low medical expense which may due to age related illness
#
# Now in order to get more clear we can comnbine both graphs

# %%
plt.figure(figsize=(13,7))

sns.lmplot(x = 'age',y = 'charges',data=df,hue='smoker')
plt.xlabel('Age')
plt.ylabel('Medical Expense')
plt.show()

# %% [markdown]
# *Now, we can clearly understand the variation in charges with respect to age and smoking habits. The medical expense of smokers is higher than that of non-smokers irrespective of age. In non-smokers, the cost of treatment increases with age which is obvious.*

# %%
# relation between BMI and medical expense
plt.figure(figsize=(13,7))
sns.distplot(df[(df.bmi > 30)]['charges'])
plt.title('')
plt.xlabel("medical expense")
plt.ylabel('bmi')
plt.show()

# %% [markdown]
# ###### Therefore, people with BMI less than 30 are spending less whereas people with bmi more than 30 are spending more.

# %%
df.drop('region',axis = 1, inplace=True)

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker      charges
# 0   19    0  27.900         0       1  16884.92400
# 1   18    1  33.770         1       0   1725.55230
# 2   28    1  33.000         3       0   4449.46200
# 3   33    1  22.705         0       0  21984.47061
# 4   32    1  28.880         0       0   3866.85520

# %%
X = df.drop('charges',axis=1)
y = df.charges

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, train_size=0.75, random_state = 42)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((1003, 5), (335, 5), (1003,), (335,))

# %%
# linear Regression
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## Making Predictions
y_pred = reg.predict(X_test)

# %%
# Model Evaluation
from sklearn import metrics
print('MAE', metrics.mean_absolute_error(y_test,y_pred))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("R2 Score",metrics.r2_score(y_test,y_pred))
# Out:
# MAE 4268.696637974912
# RMSE 5952.148688048979
# R2 Score 0.7652077247609824

# %% [markdown]
# ### Model Building & Evaluation

# %% [markdown]
# #### Linear Regression

# %%
X = df.drop('charges',axis=1)
y = df.charges

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, train_size=0.75, random_state = 2)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((1003, 5), (335, 5), (1003,), (335,))

# %%
# linear Regression
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## Making Predictions
y_pred = reg.predict(X_test)

# %%
# Model Evaluation
from sklearn import metrics
print('MAE', metrics.mean_absolute_error(y_test,y_pred))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("R2 Score",metrics.r2_score(y_test,y_pred))
# Out:
# MAE 4180.786422973238
# RMSE 6159.554567242219
# R2 Score 0.7486163979240839

# %% [markdown]
# ### to check overfitting and underfitting
# we have test in trainig data its performance is good but on testing data is low then it is overfitting

# %%
y_pr = reg.predict(X_train)

# %%
from sklearn import metrics
print('MAE', metrics.mean_absolute_error(y_train,y_pr))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_train,y_pr)))
print("R2 Score",metrics.r2_score(y_train,y_pr))
# Out:
# MAE 4199.926923359498
# RMSE 6026.239372649729
# R2 Score 0.7494581711082073

# %% [markdown]
# ##  Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 2)
poly_reg
# Out:
# PolynomialFeatures()

# %%
# Transforming the feature to higher degree
X_train_poly = poly_reg.fit_transform(X_train)

#Splitting the data
X_train,X_test,y_train,y_test = train_test_split(X_train_poly, y_train, train_size=0.75, random_state = 42)

# %%
# train the model
plr = LinearRegression()
plr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_plr = plr.predict(X_test)

# %%
from sklearn import metrics
print('MAE', metrics.mean_absolute_error(y_test,y_pred_plr))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test,y_pred_plr)))
print("R2 Score",metrics.r2_score(y_test,y_pred_plr))
# Out:
# MAE 2968.3107439132714
# RMSE 4601.0865640174015
# R2 Score 0.8422865962496552

# %% [markdown]
# **Result : My model is able to explain  80% of the total data set

# %%
# input the values
age = 21
sex = 1
bmi = 27
childern = 0
smoker = 1

# %%
charge = reg.predict([[age,sex,bmi,childern,smoker]])
print('The Charge this new patient is $',charge[0])
# Out:
# The Charge this new patient is $ 25746.780283790067

# %% [markdown]
# ### OLS Model

# %%
import statsmodels.api as sm

# %%
#add constant to predictor variables
X = sm.add_constant(X)

# %%
result = sm.OLS(y,X).fit()

# %%
# printing the summary table
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     798.0
# Date:                Wed, 13 Sep 2023   Prob (F-statistic):               0.00
# Time:                        00:16:35   Log-Likelihood:                -13551.
# No. Observations:                1338   AIC:                         2.711e+04
# Df Residuals:                    1332   BIC:                         2.715e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.205e+04    951.260    -12.670      0.000   -1.39e+04   -1.02e+04
# ...

# %%
# Regularization

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score

# %%
## Ridge Regression
Ridgemodel = Ridge()
Ridgemodel
# Out:
# Ridge()

# %%
#training the model
Ridgemodel.fit(X_train,y_train)
# Out:
# Ridge()

# %%
#testing the model 
r2_pred = Ridgemodel.predict(X_test)
r2_score(y_test,r2_pred)
# Out:
# 0.8414526768419595
