# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#remove warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
iris = pd.read_csv('iris.csv')
iris
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm         outputs
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
iris['outputs'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x = iris['sepal length in cm'], y = iris['sepal width in cm'])
# Out:
# <Axes: xlabel='sepal length in cm', ylabel='sepal width in cm'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x = iris['sepal length in cm'], y = iris['sepal width in cm'], hue = iris['outputs'])
# Out:
# <Axes: xlabel='sepal length in cm', ylabel='sepal width in cm'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x = iris['petal length in cm'], y = iris['petal width in cm'], hue = iris['outputs'])
# Out:
# <Axes: xlabel='petal length in cm', ylabel='petal width in cm'>

# %%
# from this scatter plot we can assume that any flower petal length in cm

# %% [markdown]
# # Pair Plot

# %%
plt.figure(figsize=(13, 7))
plt.title('Dimensions of Flower')

sns.pairplot(iris, hue = 'outputs', size = 4)

# %% [markdown]
# # Histogram

# %% [raw]
# Its shows the frequency od each data

# %%
iris['sepal length in cm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length in cm, Length: 150, dtype: float64

# %%
plt.figure(figsize=(12,7))
plt.title('Distribution of Sepal Width')

plt.hist(iris['sepal width in cm'])
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(iris['sepal width in cm'], bins = 25)
# Out:
# (array([ 1.,  0.,  3.,  4.,  3.,  8.,  5.,  9., 14., 10., 26., 11., 13.,
#          6., 12.,  6.,  4.,  3.,  6.,  2.,  1.,  1.,  1.,  0.,  1.]),
#  array([2.   , 2.096, 2.192, 2.288, 2.384, 2.48 , 2.576, 2.672, 2.768,
#         2.864, 2.96 , 3.056, 3.152, 3.248, 3.344, 3.44 , 3.536, 3.632,
#         3.728, 3.824, 3.92 , 4.016, 4.112, 4.208, 4.304, 4.4  ]),
#  <BarContainer object of 25 artists>)

# %% [markdown]
# # Pie Chart

# %%
# disturbution of each category in one data series

# %%
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Survived'].value_counts().values
# Out:
# array([549, 342], dtype=int64)

# %%
plt.figure(figsize=(14, 10))

labels = ['1st class','2nd class','3rd class']
explode = [0,.1,.1]
colors = ['Red','Green','Blue']
x = data['Pclass'].value_counts().values

plt.title("Proporation of Pclass ", size = 9)
plt.pie(x,explode,labels,colors,autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21ed9cd03d0>,
# ...
#  [Text(-0.17571616709359641, 1.0858746836637898, '1st class'),
#   Text(-0.5629922184066712, -1.059735703849566, '2nd class'),
#   Text(0.9561939770900165, -0.7250469489466027, '3rd class')],
#  [Text(-0.09584518205105258, 0.5922952819984307, '55.1%'),
#   Text(-0.3284121274038916, -0.6181791605789134, '24.2%'),
#   Text(0.5577798199691761, -0.42294405355218484, '20.7%')])

# %%
plt.figure(figsize=(14, 10))

labels = ['1st class','2nd class','3rd class']
explode = [0,.1,.1]
colors = ['Red','Green','Blue']
x = data['Pclass'].value_counts().values

plt.title("Proporation of pclass ", size = 9)
plt.pie(x,explode,labels,colors,autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21ed9d42e50>,
# ...
#  [Text(-0.17571616709359641, 1.0858746836637898, '1st class'),
#   Text(-0.5629922184066712, -1.059735703849566, '2nd class'),
#   Text(0.9561939770900165, -0.7250469489466027, '3rd class')],
#  [Text(-0.09584518205105258, 0.5922952819984307, '55.1%'),
#   Text(-0.3284121274038916, -0.6181791605789134, '24.2%'),
#   Text(0.5577798199691761, -0.42294405355218484, '20.7%')])

# %% [markdown]
# # Count Plot

# %%
plt.figure(figsize=(14,7))
sns.countplot(x = 'Pclass',data = data)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# plt.figure(figsize=(14,7))
# sns.countplot(x='Pclass', hue= 'Survived', data = data)

# %% [markdown]
# # Bar Chart

# %%
plt.figure(figsize=(14, 7))
sns.barplot(x = 'Pclass', y = 'Survived', hue ='Sex', data = data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [raw]
# ###  this  bargraph tells that we have three passenger class with consist male and female then define their survived chance of each class of male and female.

# %%
# this graph demonstrates the proportions of survivability of passeneger class according to their genders 
# we can conclude from 1st class has relatively more survivor compared tom

# %%
# IN Ist Class-> more than 95% female passsenger are able to survived ,where as less than 40% male passenger are able to survived
# in 2nd class-> more than 90% female passsenger are able to survived,where as less than 20% male passenger are able to survived 
# in 3rd class-> approx 50% female passeneger are able to survived ,where as less than 15% male passeneger are able to survived

# %% [markdown]
# # Distribution Plot

# %%
plt.figure(figsize=(14, 7)) # normal distributed
sns.distplot(data['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7)) # disturbed plot
sns.distplot(data['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %% [markdown]
# # Box Plot

# %% [markdown]
# ##### A box plot is known as whisker plot is created to display the summary of the set of data values having properties like minimum ,first quartile,median,third quartile and maximum

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(data['Age'])
# Out:
# <Axes: >

# %%
 # below line shows minimum value of data and then above  show 25% first quartile percent of than median  @and than 75 percentile and then above line is maximum and above dotted are outlayer

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(data['Fare'])
# Out:
# <Axes: >

# %%
# above dotted are known as maximum outlare
# Out:
#   Cell In[66], line 1
#     |# above dotted are known as maximum outlare
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Heatmap

# %%
housing = pd.read_csv('Housing (1).csv')

# %%
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# basically used for matrix

# %%
cor = housing.corr()
cor
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %%
# postitve corelation and negative corelateion And no correlation

# %%
plt.figure(figsize=(12, 7))

cor = housing.corr()
sns.heatmap(cor, annot = True, cmap = 'Spectral_r')
plt.show()

# %%
# above heatmap shoes differ the relation bw price,area,bedrooms,bathrooms,stories and parking like dark red is directly proportionl to itself so its all diagnol element is dark red and like

# %%
iris
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm         outputs
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
#petal_length_max = iris.petal_length.max()

# %%
m = iris['petal length in cm'].max()
m
n = iris['petal length in cm'].replace(m,7.5)

# %% [markdown]
# m|

# %%
# #Load the iris dataset and Find only those records whose sepal_length = 5.1 and sepal_width = 3.5

# %%
#iris

# %%
#file=(iris['sepal length in cm'] == 5.1 , iris['sepal width in cm'] == 3.5)
#long_petal_data = iris['sepal length in cm'] == 4  and iris['sepal width in cm'] == 3.5

# %%
file
# Out:
# (0       True
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  145    False
#  146    False
#  147    False
#  148    False
#  149    False
#  Name: sepal length in cm, Length: 150, dtype: bool,
#  0       True
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  145    False
#  146    False
#  147    False
#  148    False
#  149    False
#  Name: sepal width in cm, Length: 150, dtype: bool)

# %%
list1 = [54, 44, 27, 79, 91, 41]
a = list1.pop(4)
list1.insert(1,a)

# %%
list1
# Out:
# [54, 91, 44, 27, 79, 41]
